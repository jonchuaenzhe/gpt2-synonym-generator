# %% [markdown]
# # Generate Synonyms Using GPT2 (Jonathan Chua)
# This model uses an existing corpus of word-synonym pairs to train a GPT2 model to predict synonyms of new words. Synonyms of words were taken from https://www.wordsapi.com/, then fed into the model to train.
#
# Steps for obtaining and preparing of the corpus can be found in this notebook: https://colab.research.google.com/drive/1w00viidTv7xXRDotvP-og9X0l2d6u2vK?usp=sharing

# %% [markdown]
# ## Set up

# %%
# !pip install -q tensorflow-gpu==1.13.1
# !pip install -q gpt_2_simple

# %%
import gpt_2_simple as gpt2
from datetime import datetime
from google.colab import files
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
gpt2.download_gpt2(model_name="345M")
# Out:
# Fetching checkpoint: 1.05Mit [00:00, 312Mit/s]
# Fetching encoder.json: 1.05Mit [00:00, 80.4Mit/s]
# Fetching hparams.json: 1.05Mit [00:00, 227Mit/s]
# Fetching model.ckpt.data-00000-of-00001: 1.42Git [00:09, 143Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 247Mit/s]
# Fetching model.ckpt.meta: 1.05Mit [00:00, 92.2Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:00, 133Mit/s]

# %%
gpt2.mount_gdrive()
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# ## Import corpus of words stored as a text file

# %%
file_name = "train_string.txt"

# %%
f = open(file_name, "r")

string = f.read()

# %%
print(len(string))
string
# Out:
# 515310
# "removed <|startgen|> distant remote <|endgen|> pacifism <|startgen|> pacificism passivism <|endgen|> collected <|startgen|> equanimous poised self-collected self-contained self-possessed <|endgen|> ant <|startgen|> emmet pismire <|endgen|> lend <|startgen|> add bestow bring contribute impart <|endgen|> indication <|startgen|> indicant reading denotation <|endgen|> grant <|startgen|> award subsidisation subsidization allow assignment <|endgen|> chance <|startgen|> opportunity bump encounter find happen <|endgen|> barker <|startgen|> bow-wow doggie doggy pooch <|endgen|> restoration <|startgen|> regaining restitution return refurbishment renovation <|endgen|> wire <|startgen|> telegram electrify cable telegraph <|endgen|> ford <|startgen|> fording crossing <|endgen|> interpret <|startgen|> construe see read translate understand <|endgen|> fusion <|startgen|> coalition merger unification <|endgen|> driving <|startgen|> drive impulsive <|endgen|> decision <|startgen|> conclusion determination decisiveness <|endgen|> brittle <|startgen|> toffee toffy brickle brickly unannealed <|endgen|> alone <|startgen|> solo unaccompanied entirely exclusively only <|endgen|> vindication <|startgen|> defence defense exoneration <|endgen|> accounting <|startgen|> account accountancy <|endgen|> accomplish <|startgen|> achieve attain reach action execute <|endgen|> grain <|startgen|> texture ingrain granulate caryopsis cereal <|endgen|> possess <|startgen|> have own <|endgen|> refreshed <|startgen|> fresh invigorated reinvigorated <|endgen|> genteel <|startgen|> civilised civilized cultivated cultured polite <|endgen|> productive <|startgen|> fat fertile rich generative <|endgen|> surgery <|startgen|> or operation <|endgen|> declare <|startgen|> announce adjudge hold <|endgen|> value <|startgen|> esteem prise prize respect appreciate <|endgen|> inverted <|startgen|> upside-down anatropous <|endgen|> pants <|startgen|> bloomers drawers knickers <|endgen|> hurt <|startgen|> damage harm scathe ache suffer <|endgen|> hazy <|startgen|> bleary blurred blurry foggy fuzzy <|endgen|> apocalyptic <|startgen|> apocalyptical revelatory <|endgen|> one-fourth <|startgen|> fourth one-quarter quarter quartern <|endgen|> investment <|startgen|> investiture investing <|endgen|> thorough <|startgen|> arrant complete consummate double-dyed everlasting <|endgen|> fixing <|startgen|> fastener fastening holdfast fixation fix <|endgen|> mystery <|startgen|> enigma secret whodunit <|endgen|> client <|startgen|> customer guest node <|endgen|> foam <|startgen|> froth effervesce fizz sparkle <|endgen|> pervasive <|startgen|> permeant permeating permeative <|endgen|> fanny <|startgen|> arse ass backside behind bottom <|endgen|> meanwhile <|startgen|> interim lag meantime <|endgen|> pleasure <|startgen|> pleasance delight joy <|endgen|> cone <|startgen|> conoid strobile strobilus <|endgen|> class <|startgen|> year stratum assort classify separate <|endgen|> hostile <|startgen|> uncongenial unfriendly <|endgen|> aberration <|startgen|> distortion aberrance aberrancy deviance <|endgen|> dwelling <|startgen|> abode domicile habitation home <|endgen|> site <|startgen|> locate place situation website <|endgen|> equivalent <|startgen|> eq tantamount <|endgen|> speak <|startgen|> talk address mouth utter verbalise <|endgen|> arranging <|startgen|> arrangement transcription <|endgen|> territory <|startgen|> district dominion soil <|endgen|> melody <|startgen|> air line strain tune <|endgen|> apply <|startgen|> hold practice use give enforce <|endgen|> regular <|startgen|> veritable steady even fixture habitue <|endgen|> blister <|startgen|> bleb bulla scald whip vesicate <|endgen|> sparkling <|startgen|> effervescent scintillation twinkle <|endgen|> despised <|startgen|> detested hated scorned <|endgen|> strangled <|startgen|> smothered stifled suppressed <|endgen|> marketing <|startgen|> merchandising selling <|endgen|> dying <|startgen|> anxious death demise <|endgen|> upheaval <|sta ...

# %% [markdown]
# ## Training

# %%
sess = gpt2.start_tf_sess()

gpt2.finetune(sess,
              dataset=file_name,
              model_name='345M',
              steps=2500,
              learning_rate = 2e-5,
              restore_from='fresh',
              print_every=10,
              sample_every=200,
              save_every=500
              )
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# Loading checkpoint models/345M/model.ckpt
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from models/345M/model.ckpt
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading dataset...
# 100%|██████████| 1/1 [00:01<00:00,  1.46s/it]
# dataset has 157096 tokens
# Training...
# [10 | 40.86] loss=2.32 avg=2.32
# [20 | 71.45] loss=2.12 avg=2.22
# [30 | 101.84] loss=2.13 avg=2.19
# [40 | 132.21] loss=2.18 avg=2.19
# [50 | 162.74] loss=1.87 avg=2.12
# [60 | 193.32] loss=2.26 avg=2.15
# [70 | 223.73] loss=1.82 avg=2.10
# [80 | 254.08] loss=1.99 avg=2.09
# [90 | 284.46] loss=2.00 avg=2.08
# [100 | 314.99] loss=2.02 avg=2.07
# [110 | 345.53] loss=2.03 avg=2.07
# [120 | 375.90] loss=2.05 avg=2.06
# [130 | 406.23] loss=1.89 avg=2.05
# [140 | 436.70] loss=1.90 avg=2.04
# [150 | 467.22] loss=1.98 avg=2.03
# [160 | 497.70] loss=1.79 avg=2.02
# [170 | 528.02] loss=2.04 avg=2.02
# [180 | 558.32] loss=1.81 avg=2.01
# [190 | 588.78] loss=1.95 avg=2.00
# [200 | 619.20] loss=1.98 avg=2.00
# ======== SAMPLE 1 ========
# ||----|-|--|-------|-------------------------| \______________| |__|_|__|_| |_| | |_| | | __| |_| |_| |_____| \_______ (__)__| __/| |__/| | | ( | \___|\___| \ | \ |_| |/|_|_|
#
# {12}
#
# |_________|___/| ____\__|____\__|_____| \__| |__\/ |__/ |__/( |__/| |___) |_| |_| | |( {12} |_________|___/| \__| \___|\___|_| \_________|___/| \__| |__\/ |__/ |__/( |__/| |___) |_| |_| _| \______________________| {12} \______________| __| |__| _|__/ |_| | | \___|\___| \ \ |_| |/|_|_| \ \ \_| __|_/ \___|__/ |__/| | _| \__/ \___| \_| \_\__________| {12} \______________| __| |__|_|__/ |_| |_| |__/ |_| |__/|_| |____| \_______ (__)___| __/|_| |_| |_|____| \_______ (__)___| __/|_| |_|
#
# {13}
#
# |___________|___/| ____\__|____\__|_____| \__| |__\/ |__/ |__/( |__/| |___) |_| |_| | |( {13} |___________|___/| \__| \___|\___|_| \___________|___/| \__| |__\/ |__/ |__/( |__/| |___) |_| |_| |_| |(_| <-- {__} |__) |_| |_| ____ |_| <--
#
# {14}
#
# |___________|___/| ____\__|____\__|_____| \__| |__\/ |__|____|__/ |_| |_| | |( {14} |___________|___/| \__| \___|\___|_| \___________|___/| \__| |__\/ |__|____|__/ |_| |_| |__/ |_| |__/|_| |____| \_______ (__)___| _|__/ \___|__/ |__/| _| \__/ \___| \_\__________|
#
# {15}
#
# |___________|___/| ____\__|____\__|_____| \__| |__\/ |__|____|__/ |_| |_| |__/ |_| |_| | (_| <-- {__} |__) |_| |_| ____ |_| <--
#
# {16}
#
# |___________|___/| ____\__|____\__|_____| \__| |__\/ |__| / __| |__| |_______ (_) <--
#
# {17}
#
# |___________|___/| ____\__|____\__|_____| \__| |__\/ |__|___/ |_| |_| | _| | <-- {__} |__) |_| |_| ____ |_| <--
#
# {18}
#
# |___________|___/| ____\__|____\__|_____| \__| |__\/ |__| / __| |__| |__/ | __/|___/ | (_| <-- {__} |__) |_| |_| <--
#
# {19}
#
# |___________|___/| ____\__|____\__|_____| \__| |__\/ |__| / __| |__| |_______ (_) <--
#
# {20}
#
# |___________|___/| ____\__|____\__|_____| \__| |__\/ |__| / __| |__| |_______ (_) <--
#
# {21}
#
# |___________|___/| ____\__|____\__|_____| \__| |__\/ |__| _)| \__/ \___|_| \__| <--
#
# {22}
#
#
# [210 | 689.01] loss=1.92 avg=2.00
# [220 | 719.38] loss=1.62 avg=1.98
# [230 | 749.93] loss=1.90 avg=1.98
# [240 | 780.47] loss=1.79 avg=1.97
# [250 | 810.83] loss=1.77 avg=1.96
# [260 | 841.13] loss=1.78 avg=1.95
# [270 | 871.60] loss=1.96 avg=1.95
# [280 | 902.09] loss=1.91 avg=1.95
# [290 | 932.49] loss=1.89 avg=1.95
# [300 | 962.75] loss=1.71 avg=1.94
# [310 | 993.08] loss=1.72 avg=1.93
# [320 | 1023.54] loss=1.59 avg=1.92
# [330 | 1054.04] loss=1.84 avg=1.91
# [340 | 1084.42] loss=1.69 avg=1.91
# [350 | 1114.73] loss=1.65 avg=1.90
# [360 | 1145.16] loss=1.80 avg=1.89
# [370 | 1175.68] loss=1.32 avg=1.88
# [380 | 1206.15] loss=1.70 avg=1.87
# [390 | 1236.44] loss=1.76 avg=1.87
# [400 | 1266.72] loss=1.44 avg=1.85
# ======== SAMPLE 1 ========
# |startgen|> china china-and-the-insurgent-contingent <|endgen|> flint <|startgen|> flint-strike flint-capped <|endgen|> head <|startgen|> head-start head-head <|endgen|> tiddly-winks <|startgen|> claret-colored <|endgen|> dented <|startgen|> chipped-edged broken mended <|endgen|> cairns <|startgen|> citrons cymrucines <|endgen|> jade <|startgen|> jade-gray enmity enmity-and-fear enmity <|endgen|> sashay <|startgen|> skim lark larkboat <|endgen|> longhorn <|startgen|> hoarse hoarsely hoarse stout <|endgen|> conforming <|startgen|> conformist conformist-ish <|endgen|> glee <|startgen|> giddy jubilation jubilationism joy <|endgen|> idleness <|startgen|> unwholesome jaded indifference lethargy <|endgen|> smock <|startgen|> shamrock tuxedo tuxedo-do <|endgen|> santa <|startgen|> santa tate tor. toronto <|endgen|> rambling <|startgen|> backlong rambling <|endgen|> gothic <|startgen|> gothic grimdark <|endgen|> vista <|startgen|> viewport viewportpark <|endgen|> vioacious <|startgen|> effervescent effervescent-hearted effervescent-spirited effervescent-hearted <|endgen|> scottish <|startgen|> spain spain-shire <|endgen|> poco <|startgen|> poco-coiffure poco-effusive effervescent <|endgen|> greek <|startgen|> greek-ian grecian Greek phoenician <|endgen|> mason <|startgen|> mason-cuirass mason-chime <|endgen|> scottish <|startgen|> spain spain-shire <|endgen|> teddy <|startgen|> toddy toda mitt <|endgen|> spruce <|startgen|> clarinets clarinet clarinouse <|endgen|> rickety <|startgen|> rickety rickety-based rick-it <|endgen|> huffy <|startgen|> huffyish fluffy sweet-tempered sweet-tempered <|endgen|> longhaired <|startgen|> hanaficent hoity-toity jolly lad <|endgen|> hollering <|startgen|> boisterous bellowing bellowing-in-pleasure bellowing-to <|endgen|> otiose <|startgen|> lascivious coy coy-faced coy-shade <|endgen|> hokey <|startgen|> jolly jolly-hearted happy-go-lucky trumped-up <|endgen|> teddy <|startgen|> toddy toda mitt <|endgen|> shivering <|startgen|> shivering miserable wretched <|endgen|> santorum <|startgen|> scotch-upon-the-santana santas <|endgen|> pinnace <|startgen|> yawl yawlbird yawlbirdbird jetty <|endgen|> pixie <|startgen|> pixie-hued halo-eyed <|endgen|> naught <|startgen|> empty nada empty-simpler <|endgen|> wah <|startgen|> bang bam bam-bang bam <|endgen|> mens <|startgen|> mens' manly <|endgen|> unbound <|startgen|> unbounden unboundenly <|endgen|> chinese <|startgen|> chinese-yuan yuan yin yang <|endgen|> miami <|startgen|> miami-dade metl miamihenry <|endgen|> ghoulish <|startgen|> scary ghastly ghoulish ghoulish-like <|end
#
# [410 | 1333.77] loss=1.79 avg=1.85
# [420 | 1364.17] loss=1.48 avg=1.84
# [430 | 1394.46] loss=1.52 avg=1.83
# [440 | 1424.92] loss=1.47 avg=1.82
# [450 | 1455.35] loss=1.30 avg=1.81
# [460 | 1485.76] loss=1.23 avg=1.79
# [470 | 1516.04] loss=1.63 avg=1.79
# [480 | 1546.32] loss=1.33 avg=1.78
# [490 | 1576.76] loss=1.51 avg=1.77
# [500 | 1607.26] loss=1.53 avg=1.76
# Saving checkpoint/run1/model-500
# [510 | 1645.79] loss=1.62 avg=1.76
# [520 | 1676.26] loss=1.49 avg=1.75
# [530 | 1706.94] loss=1.37 avg=1.74
# [540 | 1737.63] loss=1.54 avg=1.74
# [550 | 1768.19] loss=1.65 avg=1.74
# [560 | 1798.72] loss=1.67 avg=1.73
# [570 | 1829.32] loss=1.45 avg=1.73
# [580 | 1859.69] loss=1.31 avg=1.72
# [590 | 1889.97] loss=1.35 avg=1.71
# [600 | 1920.33] loss=1.23 avg=1.70
# ======== SAMPLE 1 ========
#  <|endgen|> well <|startgen|> well-being well-being-wise well-being-pleasing pleasurable <|endgen|> o.k. <|startgen|> alright okay <|endgen|> crowing <|startgen|> hubris gallantry gallop galloping galloping swaggering <|endgen|> wreath <|startgen|> braid wreathful wreathe <|endgen|> sifting <|startgen|> searching consideration thought experiment experiment <|endgen|> wicket <|startgen|> birdcage cage <|endgen|> pelt <|startgen|> coating shell adorn decorate fortify <|endgen|> fifties <|startgen|> 1950s mid-fifties the decade <|endgen|> tumbling <|startgen|> tumbling downslope tumble plunging tumble <|endgen|> fifties <|startgen|> 1950s mid-fifties the decade <|endgen|> tattered <|startgen|> mangled mangled <|endgen|> nimble <|startgen|> agile easy-going light hard-nosed <|endgen|> glutton <|startgen|> gluttonous fussy picky picky-picking gastronome <|endgen|> ponderous <|startgen|> awkward obdurate impudent bootlegger <|endgen|> wracked <|startgen|> ragged raggedness rheumy kvetch <|endgen|> baying <|startgen|> baying cross cross-legged <|endgen|> blase <|startgen|> soft clean suave <|endgen|> babbling <|startgen|> hushed hushed hushed hushing chortling <|endgen|> fifties <|startgen|> 1950s mid-fifties the decade <|endgen|> grim <|startgen|> gloomy dark grimy hard-boiled <|endgen|> scotch <|startgen|> shade bottle bottle spruce <|endgen|> griminess <|startgen|> grimness scotchness <|endgen|> fifty <|startgen|> 50 bev. 50 bev. dol. <|endgen|> clapping <|startgen|> clapping clapping <|endgen|> five <|startgen|> 5 bev. bev. 5 dol. <|endgen|> jolly <|startgen|> jolly-good jollygood <|endgen|> fifty <|startgen|> 50 bev. bev. dol. <|endgen|> forty <|startgen|> 40 ha bev. ha dol. 70 <|endgen|> fifties <|startgen|> 1950s mid-fifties the decade <|endgen|> bev <|startgen|> beviness advent bev. <|endgen|> stony <|startgen|> slate-gray slate-gray-grey <|endgen|> wailing <|startgen|> lamenting wailful malingering <|endgen|> grieve <|startgen|> lamentation lament <|endgen|> malaise <|startgen|> regret ruefulness grieve <|endgen|> five <|startgen|> 5 bev. bev. <|endgen|> rueful <|startgen|> grieved wrothful <|endgen|> middling <|startgen|> average par laggard short-handed lacking <|endgen|> half-wit <|startgen|> incompetent middling-grade amateur amateur amateurish <|endgen|> fifteen <|startgen|> 15 xl bev. bev yap. yam <|endgen|> eighteen <|startgen|> xxiii bev. bev yap. yam <|endgen|> nineteen <|startgen|> 19 xxiiii bev. bev yap. yam <|endgen|> middling <|startgen|> ordinary amateur amateur amateurish amateurish amateur <|endgen|> seventeen <|startgen|> 17 xl i y bev. bev yap. yam <|endgen|> fifty <|startgen|> 50 bev. bev yap. yam <|endgen|> half-wit <|startgen|> incompetent amateurish amateurish amateurish amateurish amateur <|endgen|> two
#
# [610 | 1987.12] loss=1.46 avg=1.69
# [620 | 2017.52] loss=1.19 avg=1.68
# [630 | 2047.90] loss=1.22 avg=1.67
# [640 | 2078.41] loss=1.43 avg=1.67
# [650 | 2108.87] loss=1.75 avg=1.67
# [660 | 2139.19] loss=1.14 avg=1.66
# [670 | 2169.42] loss=1.17 avg=1.65
# [680 | 2199.74] loss=0.97 avg=1.64
# [690 | 2230.21] loss=1.49 avg=1.63
# [700 | 2260.70] loss=1.33 avg=1.63
# [710 | 2291.00] loss=1.08 avg=1.62
# [720 | 2321.30] loss=1.25 avg=1.61
# [730 | 2351.72] loss=1.25 avg=1.60
# [740 | 2382.19] loss=0.97 avg=1.59
# [750 | 2412.55] loss=1.25 avg=1.58
# [760 | 2442.80] loss=1.12 avg=1.58
# [770 | 2473.25] loss=1.26 avg=1.57
# [780 | 2503.74] loss=0.86 avg=1.56
# [790 | 2534.16] loss=0.99 avg=1.55
# [800 | 2564.44] loss=1.28 avg=1.54
# ======== SAMPLE 1 ========
# gen|> rah-rah <|startgen|> rumble romp <|endgen|> fag <|startgen|> faget top faggy fanny <|endgen|> aborigines <|startgen|> aboriginal aboriginal races wild-blazed wildcat <|endgen|> faggy <|startgen|> fannyfag fanny-fanny fannycat fannycage <|endgen|> trimmer <|startgen|> more manageable fatter <|endgen|> fiddle <|startgen|> transpose play <|endgen|> yawl <|startgen|> yawl-rig gaffe humbug laxity <|endgen|> slipper <|startgen|> skid rowership tugboat <|endgen|> yank <|startgen|> drag rap pull net <|endgen|> twirler <|startgen|> thumpty twirgger twirler <|endgen|> beamer <|startgen|> boom bally tin tinny adorn <|endgen|> lager <|startgen|> lager-type lager-cider ale muscovado <|endgen|> tiring <|startgen|> exhausting wearing wearying <|endgen|> buss <|startgen|> bum loo corner bin <|endgen|> nip <|startgen|> nick thune tick toss <|endgen|> fudge <|startgen|> fabricate fake phony fakeness thievishness <|endgen|> bend <|startgen|> crinkle curl twist clyster twist <|endgen|> smolder <|startgen|> ball shimmer sparkle glare spotlight <|endgen|> tiring <|startgen|> exhausting wearing wearying <|endgen|> jollyman <|startgen|> jimmyman stoutjim stoutman stodgy <|endgen|> loom <|startgen|> be float hover hoist sway tilt <|endgen|> glimmer <|startgen|> glowing fire shine gleam gleam <|endgen|> thud <|startgen|> splash splashshott runny <|endgen|> wily <|startgen|> foreboding coy sly <|endgen|> nip <|startgen|> nick ticktock twik ticktock <|endgen|> flicker <|startgen|> flashing flash flashflick flicker flick <|endgen|> o.k. <|startgen|> alright okay alright <|endgen|> cadaver <|startgen|> exhumed exhumed embalmed <|endgen|> viper <|startgen|> parvo toxoid <|endgen|> o.k. <|startgen|> okay okay okay <|endgen|> puddle <|startgen|> goop goopball goopballment gopball <|endgen|> lather <|startgen|> aiff aiffication aiffuss crap <|endgen|> jukebox <|startgen|> turntable record player turntable <|endgen|> scottish <|startgen|> scotch tartanus <|endgen|> tiring <|startgen|> exhausting wearisome tiresome <|endgen|> fagget <|startgen|> faghead fagtail <|endgen|> gape <|startgen|> groan constrict restrict mawkish <|endgen|> hush <|startgen|> quiet quieten quieten still <|endgen|> shiver <|startgen|> thrill shiver thrill thrill (nonstop) <|endgen|> incommode <|startgen|> interminably interminably <|endgen|> pang <|startgen|> agony agony shock ache <|endgen|> wiggly <|startgen|> wiggly-woggley wiggle wigglytyy wiggletail <|endgen|> slovenly <|startgen|> amateurish amateurish underhanded low <|endgen|> bawdy <|startgen|> ball gown gaudy gonzo cheesy <|endgen|> tattered <|startgen|> haggard worn <|endgen|> clumsily <|startgen|> lascivious lasciviousness slatternly crude <|endgen|> stinking <|startgen|> nauseating nauseating nauseous st
#
# [810 | 2631.06] loss=0.85 avg=1.53
# [820 | 2661.42] loss=0.85 avg=1.52
# [830 | 2691.68] loss=0.99 avg=1.51
# [840 | 2721.98] loss=1.23 avg=1.50
# [850 | 2752.43] loss=0.78 avg=1.49
# [860 | 2782.92] loss=1.53 avg=1.49
# [870 | 2813.24] loss=1.58 avg=1.49
# [880 | 2843.51] loss=0.91 avg=1.48
# [890 | 2873.85] loss=0.94 avg=1.47
# [900 | 2904.32] loss=1.03 avg=1.47
# [910 | 2934.67] loss=1.09 avg=1.46
# [920 | 2964.95] loss=1.00 avg=1.45
# [930 | 2995.23] loss=1.20 avg=1.45
# [940 | 3025.71] loss=1.76 avg=1.45
# [950 | 3056.20] loss=0.92 avg=1.44
# [960 | 3086.59] loss=1.14 avg=1.44
# [970 | 3116.96] loss=0.83 avg=1.43
# [980 | 3147.37] loss=0.82 avg=1.42
# [990 | 3177.82] loss=0.63 avg=1.41
# [1000 | 3208.20] loss=0.73 avg=1.40
# Saving checkpoint/run1/model-1000
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:966: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# ======== SAMPLE 1 ========
# startgen|> stinking stink odious sinsemilla <|endgen|> workable <|startgen|> workable workable adaptable conformable <|endgen|> bequest <|startgen|> gratuity devise save grant will <|endgen|> dapper <|startgen|> dashing jaunty portly raffish beau <|endgen|> wicker <|startgen|> caning wickerwork <|endgen|> induce <|startgen|> induct conjure evoke excite incite <|endgen|> beaver <|startgen|> butcher boar deer deer antlers <|endgen|> stony <|startgen|> dull gray grayish grey <|endgen|> cuckold <|startgen|> femme fatale femme fatale femme <|endgen|> jigsaw <|startgen|> jigsaw-piece jigsaw-suited <|endgen|> impendence <|startgen|> impending consequence consequent entailment <|endgen|> boodle <|startgen|> latch latch-key clatch clink <|endgen|> jean <|startgen|> denim dungaree <|endgen|> drench <|startgen|> soak froth drizzle rain punt <|endgen|> wicker <|startgen|> caning wickerwork <|endgen|> dainty <|startgen|> handsome modish rakish suave <|endgen|> bend <|startgen|> crinkle curl creep jut <|endgen|> gladiator <|startgen|> gladiator fighter <|endgen|> raucousness <|startgen|> noise hooliganism unmannerliness hooliganism <|endgen|> bend <|startgen|> crinkle curl creep jut <|endgen|> livery <|startgen|> breeding stock <|endgen|> tucker <|startgen|> agitate contend button quarrel <|endgen|> flapping <|startgen|> flapping flap flapjacking flapjacking <|endgen|> glowering <|startgen|> gruff ungainly crude rude <|endgen|> idleness <|startgen|> idling nonperformance <|endgen|> hound <|startgen|> hunt trace trace dog find <|endgen|> livery <|startgen|> breeding stock <|endgen|> fiddle <|startgen|> twiddle fiddle-bass range tune <|endgen|> airy <|startgen|> enveloping enveloping-airy alfresco <|endgen|> beep <|startgen|> rangy roar resounder beep-ety <|endgen|> incisive <|startgen|> keen knifelike penetrating keen knifelike <|endgen|> ointment <|startgen|> cataplasm materiel <|endgen|> taint <|startgen|> contaminant contaminant contaminative <|endgen|> babbling <|startgen|> babble bullshit chatter off-topic <|endgen|> idling <|startgen|> nonperformance nonperformance <|endgen|> bend <|startgen|> crinkle curl creep jut <|endgen|> jagged <|startgen|> serrated serrated serrated sharp <|endgen|> glazed <|startgen|> glass-and-steel herky-pyramid hexagonal <|endgen|> attitude <|startgen|> position posture <|endgen|> rattle <|startgen|> rumble ring rattling <|endgen|> holler <|startgen|> booming shriek roar <|endgen|> impudence <|startgen|> caprice lucky chance proskiness <|endgen|> lesh <|startgen|> leshy lynam <|endgen|> pail <|startgen|> pailful pitcher carte can <|endgen|> mamma <|startgen|> ma mama mammy mom momma <|endgen|> bilk <|startgen|> bilkle buck bungler mangler misdeed <|endgen|> gaunt <|startgen|> blue deathly corpulent skeletal skeletal <|endgen|> blossom <|startgen|> flower flower fragrance fragrance bloom <|endgen|> tusk <|startgen|> ailerolateral <|endgen|> flapping <|startgen|> flap
#
# [1010 | 3282.01] loss=0.83 avg=1.39
# [1020 | 3312.52] loss=1.24 avg=1.39
# [1030 | 3342.92] loss=0.84 avg=1.38
# [1040 | 3373.19] loss=1.39 avg=1.38
# [1050 | 3403.47] loss=0.67 avg=1.37
# [1060 | 3433.88] loss=0.67 avg=1.36
# [1070 | 3464.36] loss=0.67 avg=1.34
# [1080 | 3494.72] loss=0.67 avg=1.33
# [1090 | 3524.99] loss=0.64 avg=1.32
# [1100 | 3555.33] loss=0.58 avg=1.31
# [1110 | 3585.81] loss=0.90 avg=1.31
# [1120 | 3616.35] loss=0.70 avg=1.30
# [1130 | 3646.66] loss=0.92 avg=1.29
# [1140 | 3676.96] loss=0.63 avg=1.28
# interrupted
# Saving checkpoint/run1/model-1142
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/gpt_2_simple/gpt_2.py in finetune(sess, dataset, steps, model_name, model_dir, combine, batch_size, learning_rate, accumulate_gradients, restore_from, run_name, checkpoint_dir, sample_every, sample_length, sample_num, multi_gpu, save_every, print_every, max_checkpoints, use_memory_saving_gradients, only_train_transformer_layers, optimizer, overwrite)
#     341                     (opt_apply, loss, summary_loss),
# --> 342                     feed_dict={context: sample_batch()})
#     343
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1406         self._session, options, feed_dict, fetch_list, target_list,
# -> 1407         run_metadata)
#    1408
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-0c522bee0b1d> in <module>()
#       9               print_every=10,
#      10               sample_every=200,
# ---> 11               save_every=500
#      12               )
#
# /usr/local/lib/python3.6/dist-packages/gpt_2_simple/gpt_2.py in finetune(sess, dataset, steps, model_name, model_dir, combine, batch_size, learning_rate, accumulate_gradients, restore_from, run_name, checkpoint_dir, sample_every, sample_length, sample_num, multi_gpu, save_every, print_every, max_checkpoints, use_memory_saving_gradients, only_train_transformer_layers, optimizer, overwrite)
#     359     except KeyboardInterrupt:
#     360         print('interrupted')
# --> 361         save()
#     362
#     363
#
# /usr/local/lib/python3.6/dist-packages/gpt_2_simple/gpt_2.py in save()
#     281             sess,
#     282             os.path.join(checkpoint_path, 'model'),
# --> 283             global_step=counter-1)
#     284         with open(counter_path, 'w') as fp:
#     285             fp.write(str(counter-1) + '\n')
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py in save(self, sess, save_path, global_step, latest_filename, meta_graph_suffix, write_meta_graph, write_state, strip_default_attrs)
#    1169           model_checkpoint_path = sess.run(
#    1170               self.saver_def.save_tensor_name,
# -> 1171               {self.saver_def.filename_tensor_name: checkpoint_file})
#    1172
#    1173         model_checkpoint_path = compat.as_str(model_checkpoint_path)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1150     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#    1154       results = []
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1326     if handle is None:
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#    1330       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1332   def _do_call(self, fn, *args):
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#    1336       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1317       self._extend_graph()
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#    1321     def _prun_fn(handle, feed_dict, fetch_list):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1405     return tf_session.TF_SessionRun_wrapper(
#    1406         self._session, options, feed_dict, fetch_list, target_list,
# -> 1407         run_metadata)
#    1408
#    1409   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
ls checkpoint/run1
# Out:
# checkpoint                                   model-1000.index
# counter                                      model-1000.meta
# encoder.json                                 model-1142.data-00000-of-00001
# events.out.tfevents.1595935436.6111c5f2d344  model-1142.index
# hparams.json                                 vocab.bpe
# model-1000.data-00000-of-00001

# %%
gpt2.copy_checkpoint_to_gdrive()

# %% [markdown]
# ## Generate Text

# %% [markdown]
# download test set

# %%
import random
import json
with open('test_list.json', encoding='utf-8') as f:
  test_list = json.load(f)

len(test_list)
# Out:
# 740

# %%
test_list[:5]
# Out:
# ['bracing <|startgen|> brace brisk fresh refreshful refreshing <|endgen|>',
#  'muse <|startgen|> contemplate excogitate meditate mull ponder <|endgen|>',
#  'fabric <|startgen|> cloth material textile framework <|endgen|>',
#  'disposition <|startgen|> temperament inclination tendency disposal <|endgen|>',
#  'imperfect <|startgen|> fallible frail weak progressive <|endgen|>']

# %% [markdown]
# take the first word of each test string as the starting word

# %%
def generate_and_compare(string):
  word = string.split(' ')[0]

  gpt2.generate(sess,
              length=250,
              temperature=0.7,
              prefix=f"{word} <|startgen|>",
              truncate='<|endgen|>',
              nsamples=5,
              batch_size=5
              )
  
  print(f"true synonyms are: {string}")

# %% [markdown]
# ### Some good samples

# %%
string = test_list[random.randint(0, 739)]
generate_and_compare(string)
# Out:
# brilliance <|startgen|> brilliancy luster lustre radiance exultation
# ====================
# brilliance <|startgen|> luminancy brilliance brilliancy dynamism
# ====================
# brilliance <|startgen|> brilliancy luster lustre radiance
# ====================
# brilliance <|startgen|> brilliancy brilliance dazzle dazzle
# ====================
# brilliance <|startgen|> brilliance brilliance fulness brilliancy glories
# ====================
# true synonyms are: brilliance <|startgen|> genius blaze glare grandeur grandness <|endgen|>

# %%
string = test_list[random.randint(0, 739)]
generate_and_compare(string)
# Out:
# tribute <|startgen|> homage respect due thankfulness thank
# ====================
# tribute <|startgen|> due gratitude thanks thanks
# ====================
# tribute <|startgen|> gratitude givers giveers show-off
# ====================
# tribute <|startgen|> amour attendant attendant-at-arms attendant
# ====================
# tribute <|startgen|> pledge burthen stripe tincture
# ====================
# true synonyms are: tribute <|startgen|> protection testimonial <|endgen|>

# %%
string = test_list[random.randint(0, 739)]
generate_and_compare(string)
# Out:
# labor <|startgen|> manual work manualisation
# ====================
# labor <|startgen|> work do house care hair
# ====================
# labor <|startgen|> work do part
# ====================
# labor <|startgen|> grind grindout buttock buttockwork carver carverage
# ====================
# labor <|startgen|> job process undertaking jut protrude protrude outgrowth
# ====================
# true synonyms are: labor <|startgen|> labour proletariat project task undertaking <|endgen|>

# %%
string = test_list[random.randint(0, 739)]
generate_and_compare(string)
# Out:
# nurture <|startgen|> nurture nurture raise trained bred breed
# ====================
# nurture <|startgen|> educate groom train educate train-up
# ====================
# nurture <|startgen|> educate groom raise model
# ====================
# nurture <|startgen|> foster raise groom raise progenitor
# ====================
# nurture <|startgen|> train groom raise educate groom
# ====================
# true synonyms are: nurture <|startgen|> raising rearing foster nourish sustain <|endgen|>

# %%
string = test_list[random.randint(0, 739)]
generate_and_compare(string)
# Out:
# evident <|startgen|> indisputable undeniable solid
# ====================
# evident <|startgen|> undeniable undeniable unmistakable
# ====================
# evident <|startgen|> indisputable undeniable undeniable undeniable
# ====================
# evident <|startgen|> undeniable undeniable unmistakable
# ====================
# evident <|startgen|> inevitable inevitable of-favor
# ====================
# true synonyms are: evident <|startgen|> discernible observable apparent manifest palpable <|endgen|>

# %%
string = test_list[random.randint(0, 739)]
generate_and_compare(string)
# Out:
# disposition <|startgen|> attitude outlook look
# ====================
# disposition <|startgen|> mind-set mindset mindset attitude posture
# ====================
# disposition <|startgen|> attitude attitude disposition
# ====================
# disposition <|startgen|> disposition feeling
# ====================
# disposition <|startgen|> state of mind mental status
# ====================
# true synonyms are: disposition <|startgen|> temperament inclination tendency disposal <|endgen|>

# %% [markdown]
# ### Some bad samples

# %%
string = test_list[random.randint(0, 739)]
generate_and_compare(string)
# Out:
# auxiliary <|startgen|> auxiliary adjunct services
# ====================
# auxiliary <|startgen|> auxiliary nuncio
# ====================
# auxiliary <|startgen|> auxiliary supporting helper
# ====================
# auxiliary <|startgen|> auxiliary help support adjunct
# ====================
# auxiliary <|startgen|> auxiliary annunciate prophetic
# ====================
# true synonyms are: auxiliary <|startgen|> subsidiary supplemental supplementary aide accessory <|endgen|>

# %%
string = test_list[random.randint(0, 739)]
generate_and_compare(string)
# Out:
# pointer <|startgen|> episode cameo appearance pitting
# ====================
# pointer <|startgen|> radiative radiant cradle foundation
# ====================
# pointer <|startgen|> inventor inventor joker joke
# ====================
# pointer <|startgen|> balmy regular patchwork
# ====================
# pointer <|startgen|> capture find grab touch
# ====================
# true synonyms are: pointer <|startgen|> cursor arrow <|endgen|>

# %%
string = test_list[random.randint(0, 739)]
generate_and_compare(string)
# Out:
# follow <|startgen|> paucity scantiness scantiness scantiness
# ====================
# follow <|startgen|> ah! ahh! ahhh! ahh!
# ====================
# follow <|startgen|> bailey bair bairie chaparral scrub
# ====================
# follow <|startgen|> leger gehenna har =
# ====================
# follow <|startgen|> assent accede acquiesce
# ====================
# true synonyms are: follow <|startgen|> postdate pursue trace adopt espouse <|endgen|>

# %%
string = test_list[random.randint(0, 739)]
generate_and_compare(string)
# Out:
# cordial <|startgen|> nebbishy prickly prickly
# ====================
# cordial <|startgen|> ancestral ancestral inerrant authoritative
# ====================
# cordial <|startgen|> calling callous callous-fathered hardened
# ====================
# cordial <|startgen|> pliant tolerant
# ====================
# cordial <|startgen|> dogmatic dogmaticial dogmaticous
# ====================
# true synonyms are: cordial <|startgen|> liqueur affable amiable genial <|endgen|>

# %%
string = test_list[random.randint(0, 739)]
generate_and_compare(string)
# Out:
# design <|startgen|> repeatedly repeated
# ====================
# design <|startgen|> tiffin
# ====================
# design <|startgen|> bender bendancer contortionist contortionist contralto
# ====================
# design <|startgen|> dab rag doll tell-all
# ====================
# design <|startgen|> billy billy-crap billy-talk billywhip
# ====================
# true synonyms are: design <|startgen|> blueprint pattern figure plan aim <|endgen|>
